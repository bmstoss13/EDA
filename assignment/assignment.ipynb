# %% [markdown]
# # Assignment: Exploratory Data Analysis
# ### `! git clone https://github.com/ds4e/EDA`
# ### Do Q1 and two other questions.

# %% [markdown]
# **Q1.** In class, we talked about how to compute the sample mean of a variable $X$,
# $$
# m(X) = \dfrac{1}{N} \sum_{i=1}^N x_i
# $$
# and sample covariance of two variables $X$ and $Y$,
# $$
# \text{cov}(X,Y) = \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))(y_i - m(Y))).
# $$
# Recall, the sample variance of $X$ is
# $$
# s^2 = \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))^2.
# $$
# It can be very helpful to understand some basic properties of these statistics. If you want to write your calculations on a piece of paper, take a photo, and upload that to your GitHub repo, that's probably easiest.
#
# 1. Show that $m(a + bX) = a+b \times m(X)$.
# 2. Show that $\text{cov}(X,a+bY) = b \times \text{cov}(X,Y)$
# 3. Show that $\text{cov}(a+bX,a+bX) = b^2 \text{cov}(X,X) $, and in particular that $\text{cov}(X,X) = s^2 $.
# 4. Instead of the mean, consider the median. Consider transformations that are non-decreasing (if $x\ge x'$, then $g(x)\ge g(x')$), like $2+5 \times X$ or $\text{arcsinh}(X)$. Is a non-decreasing transformation of the median the median of the transformed variable? Explain. Does your answer apply to any quantile? The IQR? The range?
# 5. Consider a non-decreasing transformation $g()$. Is is always true that $m(g(X))= g(m(X))$?

# %% [markdown]
# # Answers to Statistical Properties of Mean and Covariance
#
# ## **Q1.** Sample Mean and Covariance Properties
#
# ### **1. Show that** $ m(a + bX) = a + b \times m(X) $.
#
# Starting with the definition of the sample mean:
# $
# m(X) = \frac{1}{N} \sum_{i=1}^{N} x_i
# $
#
# Now, consider the transformed variable $ a + bX $:
#
# $
# m(a + bX) = \frac{1}{N} \sum_{i=1}^{N} (a + bx_i)
# $
#
# Using the linearity of summation,
#
# $
# m(a + bX) = \frac{1}{N} \sum_{i=1}^{N} a + \frac{1}{N} \sum_{i=1}^{N} bx_i
# $
#
# $
# = a + b \times \frac{1}{N} \sum_{i=1}^{N} x_i
# $
#
# $
# = a + b \times m(X).
# $
#
# Thus, we have shown that:
#
# $
# m(a + bX) = a + b \times m(X).
# $
#
# ---
#
# ### **2. Show that** $ \text{cov}(X,a+bY) = b \times \text{cov}(X,Y) $.
#
# By definition, the covariance between $ X $ and $ Y $ is:
#
# $
# \text{cov}(X,Y) = \frac{1}{N} \sum_{i=1}^{N} (x_i - m(X))(y_i - m(Y)).
# $
#
# Consider the transformed variable $ a + bY $:
#
# $
# \text{cov}(X, a + bY) = \frac{1}{N} \sum_{i=1}^{N} (x_i - m(X))((a + b y_i) - m(a + bY)).
# $
#
# Using the result from part (1),
#
# $
# m(a + bY) = a + b m(Y).
# $
#
# Substituting this,
#
# $
# \text{cov}(X, a + bY) = \frac{1}{N} \sum_{i=1}^{N} (x_i - m(X))(a + b y_i - (a + b m(Y))).
# $
#
# Since the constant $ a $ cancels out,
#
# $
# \text{cov}(X, a + bY) = \frac{1}{N} \sum_{i=1}^{N} (x_i - m(X))(b(y_i - m(Y))).
# $
#
# Factoring out $ b $,
#
# $
# \text{cov}(X, a + bY) = b \times \frac{1}{N} \sum_{i=1}^{N} (x_i - m(X))(y_i - m(Y)).
# $
#
# $
# = b \times \text{cov}(X,Y).
# $
#
# Thus, we have shown that:
#
# $
# \text{cov}(X,a+bY) = b \times \text{cov}(X,Y).
# $
#
# ---
#
# ### **3. Show that** $ \text{cov}(a+bX,a+bX) = b^2 \text{cov}(X,X) $, and in particular that $ \text{cov}(X,X) = s^2 $.
#
# Using the definition of covariance,
#
# $
# \text{cov}(X, X) = \frac{1}{N} \sum_{i=1}^{N} (x_i - m(X))(x_i - m(X)).
# $
#
# $
# = \frac{1}{N} \sum_{i=1}^{N} (x_i - m(X))^2.
# $
#
# By the definition of variance,
#
# $
# s^2 = \frac{1}{N} \sum_{i=1}^{N} (x_i - m(X))^2.
# $
#
# Thus, we conclude that:
#
# $
# \text{cov}(X, X) = s^2.
# $
#
# Now, consider the transformation $ a + bX $:
#
# $
# \text{cov}(a+bX, a+bX) = b^2 \text{cov}(X, X).
# $
#
# $
# = b^2 s^2.
# $
#
# This confirms the desired result.
#
# ---
#
# ### **4. Non-Decreasing Transformations and the Median**
#
# The median of $ X $ is the value that splits the dataset into two equal halves. If $ g(X) $ is a non-decreasing transformation, then:
#
# $
# \text{Median}(g(X)) = g(\text{Median}(X)).
# $
#
# This is because non-decreasing transformations preserve the relative order of values, meaning that the median remains in the same relative position after transformation.
#
# However, this does **not** necessarily hold for other quantiles, such as the interquartile range (IQR) or the range. While quantiles like the median are order-based and preserved under non-decreasing transformations, the **difference-based** statistics (e.g., IQR = $ Q_3 - Q_1 $ and range = max - min) **are not necessarily preserved**.
#
# For example, if $ g(X) = X^2 $, the transformation affects the spread differently depending on whether values are positive or negative.
#
# ---
#
# ### **5. Is it always true that** $ m(g(X))= g(m(X)) $?
#
# No, it is not always true that:
#
# $
# m(g(X)) = g(m(X)).
# $
#
# The mean is an expectation operator, whereas $ g $ may introduce non-linearity. The only case where this holds exactly is when $ g(X) $ is a linear function, i.e., $ g(X) = a + bX $, which we proved in part (1).
#
# For general non-linear functions $ g(X) $, the expectation does not commute with $ g $, meaning:
#
# $
# m(g(X)) \neq g(m(X)).
# $
#
# This follows from Jensen’s inequality: if $ g $ is convex, then:
#
# $
# m(g(X)) \geq g(m(X)).
# $
#
# Similarly, if $ g $ is concave:
#
# $
# m(g(X)) \leq g(m(X)).
# $
#
# For example, if $ X $ is normally distributed and $ g(X) = X^2 $, then:
#
# $
# m(X^2) = \text{Var}(X) + (m(X))^2 \neq (m(X))^2.
# $
#
# Thus, in general:
#
# $
# m(g(X)) \neq g(m(X)).
# $

# %% [markdown]
# **Q2.** This question looks at financial transfers from foreign entities to American universities. In particular, from which countries and giftors are the gifts coming from, and to which institutions are they going? For this question, `.groupby([vars]).count()` and `.groupby([vars]).sum()` will be especially useful to tally the number of occurrences and sum the values of those occurrences.
#
# 1. Load the `./data/ForeignGifts_edu.csv` dataset.
# 2. For `Foreign Gift Amount`, create a histogram and describe the variable. Describe your findings.
# 3. For `Gift Type`, create a histogram or value counts table. What proportion of the gifts are contracts, real estate, and monetary gifts?
# 4. Create a kernel density plot of the log of `Foreign Gift Amount`, and then a kernel density plot of the log of `Foreign Gift Amount` conditional on gift type. Do you notice any patterns?
# 5. What are the top 15 countries in terms of the number of gifts? What are the top 15 countries in terms of the amount given?
# 6. What are the top 15 institutions in terms of the total amount of money they receive? Make a histogram of the total amount received by all institutions.
# 7. Which giftors provide the most money, in total?

# %%
#1.

import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#load dataset
df = pd.read_csv(r"C:\Users\Brian\EDA\assignment\data\ForeignGifts_edu.csv")

#view dataset
print(df.head())
# Out:
#    ID   OPEID               Institution Name          City State  \
# 0   1  102000  Jacksonville State University  Jacksonville    AL
# 1   2  104700                Troy University          Troy    AL
# 2   3  105100          University of Alabama    Tuscaloosa    AL
# 3   4  105100          University of Alabama    Tuscaloosa    AL
# 4   5  105100          University of Alabama    Tuscaloosa    AL
#
#    Foreign Gift Received Date  Foreign Gift Amount      Gift Type  \
# 0                       43738               250000  Monetary Gift
# 1                       43592               463657       Contract
# 2                       43466              3649107       Contract
# 3                       43472                 1000       Contract
# 4                       43479                49476       Contract
#
#   Country of Giftor                          Giftor Name
# 0             CHINA                                  NaN
# 1             CHINA     Confucius Institute Headquarters
# ...

# %%
#2

#view statistics
print(df["Foreign Gift Amount"].describe())

# Histogram structuring
plt.figure(figsize=(9,5))
sns.histplot(df["Foreign Gift Amount"], bins=50,kde=True)
plt.xlabel("Foreign Gift Amount")
plt.ylabel("Frequency")
plt.title("Distribution of Foreign Gift Amount")
plt.show()
# Out:
# count    2.822100e+04
# mean     5.882327e+05
# std      3.222011e+06
# min     -5.377700e+05
# 25%      5.700000e+03
# 50%      9.461500e+04
# 75%      3.761420e+05
# max      1.000000e+08
# Name: Foreign Gift Amount, dtype: float64

# %% [markdown]
# The distribution is right skewed - most foreign gifts are relatively small, but a few are very large.

# %%
#3

# Count and proportion of each gift type
gift_type_counts = df["Gift Type"].value_counts(normalize=True)
print(gift_type_counts)

# Bar plot structuring
plt.figure(figsize=(8, 5))
sns.barplot(x=gift_type_counts.index, y=gift_type_counts.values)
plt.xlabel("Gift Type")
plt.ylabel("Proportion")
plt.title("Proportion of Each Gift Type")
plt.xticks(rotation=45)
plt.show()
# Out:
# Gift Type
# Contract         0.612097
# Monetary Gift    0.387513
# Real Estate      0.000390
# Name: proportion, dtype: float64

# %% [markdown]
# Contracts are the most frequent type of gift.

# %%
#4

#transform Foreign Gift Amount to log scale
df["Log Foreign Gift Amount"] = np.log1p(df["Foreign Gift Amount"])

# Overall Kernel Density Plot
plt.figure(figsize=(8, 5))
sns.kdeplot(df["Log Foreign Gift Amount"], shade=True)
plt.xlabel("Log Foreign Gift Amount")
plt.title("Kernel Density Plot of Log Foreign Gift Amount")
plt.show()
# Out:
# C:\Users\Brian\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Brian\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Brian\AppData\Local\Temp\ipykernel_24300\2444222137.py:8: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["Log Foreign Gift Amount"], shade=True)

# %%
#conditional on gift type
plt.figure(figsize=(8, 5))
sns.kdeplot(data=df, x="Log Foreign Gift Amount", hue="Gift Type", shade=True)
plt.xlabel("Log Foreign Gift Amount")
plt.title("Kernel Density Plot of Log Foreign Gift Amount by Gift Type")
plt.show()
# Out:
# C:\Users\Brian\AppData\Local\Temp\ipykernel_24300\91568780.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df, x="Log Foreign Gift Amount", hue="Gift Type", shade=True)

# %% [markdown]
# The log transformation reduces skewness. Also, different gift types have different distributions. Contract is larger than monetaary and real estate.

# %%
#5

#count of gifts per country (top 15, as shown by nlargest function)
top_countries_count = df.groupby("Country of Giftor").size().nlargest(15)
print(top_countries_count)

# Total amount given per country (top 15)
top_countries_amount = df.groupby("Country of Giftor")["Foreign Gift Amount"].sum().nlargest(15)
print(top_countries_amount)
# Out:
# Country of Giftor
# ENGLAND            3655
# CHINA              2461
# CANADA             2344
# JAPAN              1896
# SWITZERLAND        1676
# SAUDI ARABIA       1610
# FRANCE             1437
# GERMANY            1394
# HONG KONG          1080
# SOUTH KOREA         811
# QATAR               693
# THE NETHERLANDS     512
# KOREA               452
# INDIA               434
# TAIWAN              381
# dtype: int64
# Country of Giftor
# QATAR                   2706240869
# ENGLAND                 1464906771
# CHINA                   1237952112
# SAUDI ARABIA            1065205930
# BERMUDA                  899593972
# CANADA                   898160656
# HONG KONG                887402529
# JAPAN                    655954776
# SWITZERLAND              619899445
# INDIA                    539556490
# GERMANY                  442475605
# UNITED ARAB EMIRATES     431396357
# FRANCE                   405839396
# SINGAPORE                401157692
# AUSTRALIA                248409202
# ...

# %% [markdown]
# Certain countries may contribute many small gifts, while others contribute fewer but larger gifts.

# %%
#6

#top 15 institutions in terms of the total amount of money they receive
top_institutions = df.groupby("Institution Name")["Foreign Gift Amount"].sum().nlargest(15)
print(top_institutions)

# Histogram of total amount received by institutions
plt.figure(figsize=(8, 5))
sns.histplot(df.groupby("Institution Name")["Foreign Gift Amount"].sum(), bins=50, kde=True)
plt.xlabel("Total Amount Received")
plt.ylabel("Frequency")
plt.title("Distribution of Total Foreign Gifts Received by Institutions")
plt.show()
# Out:
# Institution Name
# Carnegie Mellon University                       1477922504
# Cornell University                               1289937761
# Harvard University                                954803610
# Massachusetts Institute of Technology             859071692
# Yale University                                   613441311
# Texas A&M University                              521455050
# Johns Hopkins University                          502409595
# Northwestern University                           402316221
# Georgetown University                             379950511
# University of Chicago (The)                       364544338
# University of Colorado Boulder                    360173159
# Duke University                                   343699498
# Brigham Young University                          323509863
# Stanford University                               319561362
# University of Texas MD Anderson Cancer Center     301527419
# Name: Foreign Gift Amount, dtype: int64

# %% [markdown]
# A small number of institutions receive the majority of funds.

# %%
#7

#list of the top 15 giftors
top_giftors = df.groupby("Giftor Name")["Foreign Gift Amount"].sum().nlargest(15)
print(top_giftors)
# Out:
# Giftor Name
# Qatar Foundation                       1166503744
# Qatar Foundation/Qatar National Res     796197000
# Qatar Foundation for Education          373945215
# Anonymous                               338793629
# Saudi Arabian Cultural Mission          275221475
# HCL                                     190000000
# Church of Jesus Christ of LDS           185203715
# Emirates Institute for Advanced Sc      170641244
# QIC                                     148355497
# Anonymous #9                             96334996
# Qatar National Research Fund             79021705
# Government of Saudi Arabia               75192434
# Contracting Party                        69996984
# CMKL University                          67700000
# Royal Embassy of Saudi Arabia            67062486
# Name: Foreign Gift Amount, dtype: int64

# %% [markdown]
# Certain giftors contribute disproportionately high amounts.

# %% [markdown]
# **Q3.** This question uses the Airbnb data to practice making visualizations.
#
#   1. Load the `./data/airbnb_hw.csv` data with Pandas. This provides a dataset of AirBnB rental properties for New York City.
#   2. What are are the dimensions of the data? How many observations are there? What are the variables included? Use `.head()` to examine the first few rows of data.
#   3. Cross tabulate `Room Type` and `Property Type`. What patterns do you see in what kinds of rentals are available? For which kinds of properties are private rooms more common than renting the entire property?
#   4. For `Price`, make a histogram, kernel density, box plot, and a statistical description of the variable. Are the data badly scaled? Are there many outliers? Use `log` to transform price into a new variable, `price_log`, and take these steps again.
#   5. Make a scatterplot of `price_log` and `Beds`. Describe what you see. Use `.groupby()` to compute a desciption of `Price` conditional on/grouped by the number of beds. Describe any patterns you see in the average price and standard deviation in prices.
#   6. Make a scatterplot of `price_log` and `Beds`, but color the graph by `Room Type` and `Property Type`. What patterns do you see? Compute a description of `Price` conditional on `Room Type` and `Property Type`. Which Room Type and Property Type have the highest prices on average? Which have the highest standard deviation? Does the mean or median appear to be a more reliable estimate of central tendency, and explain why?
#   7. We've looked a bit at this `price_log` and `Beds` scatterplot. Use seaborn to make a `jointplot` with `kind=hex`. Where are the data actually distributed? How does it affect the way you think about the plots in 5 and 6?

# %%
#1.

import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#load dataset
df = pd.read_csv(r"C:\Users\Brian\EDA\assignment\data\airbnb_hw.csv")

#view dataset
print(df.head())
# Out:
#     Host Id Host Since                                Name Neighbourhood   \
# 0   5162530        NaN     1 Bedroom in Prime Williamsburg       Brooklyn
# 1  33134899        NaN     Sunny, Private room in Bushwick       Brooklyn
# 2  39608626        NaN                Sunny Room in Harlem      Manhattan
# 3       500  6/26/2008  Gorgeous 1 BR with Private Balcony      Manhattan
# 4       500  6/26/2008            Trendy Times Square Loft      Manhattan
#
#   Property Type  Review Scores Rating (bin)        Room Type  Zipcode  Beds  \
# 0     Apartment                         NaN  Entire home/apt  11249.0   1.0
# 1     Apartment                         NaN     Private room  11206.0   1.0
# 2     Apartment                         NaN     Private room  10032.0   1.0
# 3     Apartment                         NaN  Entire home/apt  10024.0   3.0
# 4     Apartment                        95.0     Private room  10036.0   3.0
#
# ...

# %%
#2

# Get dataset dimensions
print(f"Number of observations: {df.shape[0]}")
print(f"Number of variables: {df.shape[1]}")

# Display column names
print(df.columns)

# Summary of dataset
df.info()
# Out:
# Number of observations: 30478
# Number of variables: 13
# Index(['Host Id', 'Host Since', 'Name', 'Neighbourhood ', 'Property Type',
#        'Review Scores Rating (bin)', 'Room Type', 'Zipcode', 'Beds',
#        'Number of Records', 'Number Of Reviews', 'Price',
#        'Review Scores Rating'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30478 entries, 0 to 30477
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Host Id                     30478 non-null  int64
#  1   Host Since                  30475 non-null  object
#  2   Name                        30478 non-null  object
#  3   Neighbourhood               30478 non-null  object
#  4   Property Type               30475 non-null  object
#  5   Review Scores Rating (bin)  22155 non-null  float64
#  6   Room Type                   30478 non-null  object
# ...

# %%
# 3

# create a crosstab
room_property_ct = pd.crosstab(df["Room Type"], df["Property Type"])

# Display the crosstab
print(room_property_ct)

# Visualizing the crosstab
plt.figure(figsize=(12, 6))
sns.heatmap(room_property_ct, annot=True, fmt="d", cmap="coolwarm")
plt.title("Cross-tabulation of Room Type and Property Type")
plt.xlabel("Property Type")
plt.ylabel("Room Type")
plt.show()
# Out:
# Property Type    Apartment  Bed & Breakfast  Boat  Bungalow  Cabin  Camper/RV  \
# Room Type
# Entire home/apt      15669               13     7         4      1          6
# Private room         10748              155     1         0      1          1
# Shared room            685               12     0         0      0          0
#
# Property Type    Castle  Chalet  Condominium  Dorm  House  Hut  Lighthouse  \
# Room Type
# Entire home/apt       0       0           72     4    752    0           1
# Private room          1       1           22    16   1258    2           0
# Shared room           0       0            0    11     80    0           0
#
# Property Type    Loft  Other  Tent  Townhouse  Treehouse  Villa
# Room Type
# Entire home/apt   392     14     0         83          0      4
# Private room      312     29     4         52          1      4
# Shared room        49      4     0          1          3      0

# %%
#4 


df["Price"] = pd.to_numeric(df["Price"], errors="coerce") #ensure price is numerical
df = df.dropna(subset=["Price"]) #drop non-numerical values

# Summary statistics for price
print(df["Price"].describe())

# Visualizations
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

sns.histplot(df["Price"], bins=50, kde=True, ax=axes[0])
axes[0].set_title("Histogram of Price")

sns.boxplot(x=df["Price"], ax=axes[1])
axes[1].set_title("Boxplot of Price")

sns.kdeplot(df["Price"], fill=True, ax=axes[2])
axes[2].set_title("Kernel Density of Price")

plt.show()
# Out:
# count    30297.000000
# mean       153.357032
# std        108.895698
# min         10.000000
# 25%         80.000000
# 50%        125.000000
# 75%        192.000000
# max        999.000000
# Name: Price, dtype: float64

# %% [markdown]
# Right skewed distribution with many outliers (luxury properties).

# %%
# Log transformation
df["price_log"] = np.log1p(df["Price"])

# Visualizing log-transformed price
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

sns.histplot(df["price_log"], bins=50, kde=True, ax=axes[0])
axes[0].set_title("Histogram of Log(Price)")

sns.boxplot(x=df["price_log"], ax=axes[1])
axes[1].set_title("Boxplot of Log(Price)")

sns.kdeplot(df["price_log"], shade=True, ax=axes[2])
axes[2].set_title("Kernel Density of Log(Price)")

plt.show()
# Out:
# C:\Users\Brian\AppData\Local\Temp\ipykernel_24300\1076386763.py:13: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["price_log"], shade=True, ax=axes[2])

# %% [markdown]
# The log transformation improves the distribution and reduces extreme skewness.

# %%
#5
# Scatterplot of price_log vs. Beds
plt.figure(figsize=(8, 5))
sns.scatterplot(x=df["Beds"], y=df["price_log"], alpha=0.5)
plt.xlabel("Number of Beds")
plt.ylabel("Log(Price)")
plt.title("Scatterplot of Log(Price) vs. Beds")
plt.show()

# Grouping by Beds
beds_summary = df.groupby("Beds")["Price"].describe()
print(beds_summary)
# Out:
#         count        mean         std    min     25%    50%     75%    max
# Beds
# 0.0       2.0   92.000000   38.183766   65.0   78.50   92.0  105.50  119.0
# 1.0   20307.0  124.757670   75.685752   10.0   75.00  100.0  155.00  950.0
# 2.0    6561.0  186.702332  115.044205   25.0  115.00  160.0  225.00  999.0
# 3.0    2029.0  234.928043  142.288189   26.0  140.00  200.0  299.00  999.0
# 4.0     766.0  280.554830  175.512312   27.0  150.00  240.0  363.75  999.0
# 5.0     274.0  322.000000  190.319415   35.0  186.00  285.0  425.00  995.0
# 6.0     166.0  316.313253  201.157585   35.0  183.75  271.0  399.00  900.0
# 7.0      45.0  341.377778  220.116631   55.0  177.00  300.0  445.00  900.0
# 8.0      20.0  331.850000  155.652202   55.0  218.75  339.5  408.75  750.0
# 9.0      14.0  587.142857  208.351721  175.0  423.75  625.0  750.00  900.0
# 10.0     15.0  442.200000  263.926992   95.0  287.00  400.0  650.00  975.0
# ...

# %% [markdown]
# Findings: Mean prices of beds tend to increase with the bed count until around 9 beds, where it reaches its peak. However, variance is quite large. Some 1 bed pieces are extremely expensive despite the mean being low.

# %%
#6

plt.figure(figsize=(8, 5))
sns.scatterplot(x=df["Beds"], y=df["price_log"], hue=df["Room Type"], style=df["Property Type"], alpha=0.5)
plt.xlabel("Number of Beds")
plt.ylabel("Log(Price)")
plt.title("Scatterplot of Log(Price) vs. Beds by Room Type and Property Type")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()

# Group by Room Type and Property Type
room_property_summary = df.groupby(["Room Type", "Property Type"])["Price"].describe()
print(room_property_summary)
# Out:
#                                    count        mean         std    min  \
# Room Type       Property Type
# Entire home/apt Apartment        15550.0  200.210161  109.967435   10.0
#                 Bed & Breakfast     13.0  184.538462  119.814172   85.0
#                 Boat                 7.0  158.428571   51.110524  100.0
#                 Bungalow             4.0  150.750000   46.464144   87.0
#                 Cabin                1.0  250.000000         NaN  250.0
#                 Camper/RV            6.0  114.333333  107.685963   45.0
#                 Condominium         71.0  281.126761  175.313998   80.0
#                 Dorm                 4.0   44.250000   24.060687   30.0
#                 House              723.0  234.554633  159.785974   27.0
#                 Lighthouse           1.0   39.000000         NaN   39.0
#                 Loft               379.0  284.910290  184.515517   55.0
#                 Other               10.0  290.800000  273.526273   66.0
# ...

# %% [markdown]
# The room type for entire homes has the highest price on average. The property type other seems to have, on average, the highest mean price. This also appears to be true for standard deviation for both room type and property type. Median should be chosen because the data is skewed to the right.

# %%
#7

#jointploty of price_log vs. beds
sns.jointplot(data=df, x="Beds", y="price_log", kind="hex", gridsize=30, cmap="coolwarm")
plt.show()

# %% [markdown]
# Most data are clustered at lower bed counts. Few properties have many beds and high prices.

# %% [markdown]
# **Q4.** This question looks at a time series of the number of active oil drilling rigs in the United States over time. The data comes from the Energy Information Agency.
#
# 1. Load `./data/drilling_rigs.csv` and examine the data. How many observations? How many variables? Are numeric variables correctly read in by Pandas, or will some variables have to be typecast/coerced? Explain clearly how these data need to be cleaned.
# 2. To convert the `Month` variable to an ordered datetime variable, use `df['time'] = pd.to_datetime(df['Month'], format='mixed')`.
# 3. Let's look at `Active Well Service Rig Count (Number of Rigs)`, which is the total number of rigs over time. Make a line plot of this time series. Describe what you see.
# 4. Instead of levels, we want to look at change over time. Compute the first difference of  `Active Well Service Rig Count (Number of Rigs)` and plot it over time. Describe what you see.
# 5. The first two columns are the number of onshore and offshore rigs, respectively. Melt these columns and plot the resulting series.

# %%
df = pd.read_csv(r"C:\Users\Brian\EDA\assignment\data\drilling_rigs.csv")
# Basic inspection
print(df.info())  # Check data types and missing values
print(df.head())  # View first few rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 623 entries, 0 to 622
# Data columns (total 10 columns):
#  #   Column                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                       --------------  -----
#  0   Month                                                                                        623 non-null    object
#  1   Crude Oil and Natural Gas Rotary Rigs in Operation, Onshore (Number of Rigs)                 623 non-null    int64
#  2   Crude Oil and Natural Gas Rotary Rigs in Operation, Offshore (Number of Rigs)                623 non-null    int64
#  3   Crude Oil Rotary Rigs in Operation, Total (Number of Rigs)                                   623 non-null    object
#  4   Natural Gas Rotary Rigs in Operation, Total (Number of Rigs)                                 623 non-null    object
# ...

# %% [markdown]
# 623 observations, 10 variables. Some numeric variables are incorrectly read as object (strings). Columns such as "Crude Oil Rotary Rigs in Operation, Total (Number of Rigs)", "Natural Gas Rotary Rigs in Operation, Total (Number of Rigs)", "Crude Oil and Natural Gas Rotary Rigs in Operation, Horizontal Trajectory (Number of Rigs)", and a few others contain "Not Available" values, which prevent automatic conversion to numeric. Data can be cleaned by converting Month to datetime variable, converting numeric columns to proper types, handling "NA" values, dropping/handling missing values, and setting "time" as the index for time series analysis.

# %%
#2

df['time'] = pd.to_datetime(df['Month'], format='mixed')

# %%
# Line plot of total rig count over time
plt.figure(figsize=(12, 6))
plt.plot(df.index, df["Active Well Service Rig Count (Number of Rigs)"], label="Total Rigs", color="blue")
plt.xlabel("Time")
plt.ylabel("Number of Rigs")
plt.title("Active Well Service Rig Count Over Time")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# There is a steady increase in the number of active well service rigs over time. However, there are very sudden jolts in this trend where the count drops rapidly and rises back up to where it previously was.

# %%
#4

#convert to numeric
df["Active Well Service Rig Count (Number of Rigs)"] = pd.to_numeric(df["Active Well Service Rig Count (Number of Rigs)"], errors="coerce")

# Compute first difference
df["rig_change"] = df["Active Well Service Rig Count (Number of Rigs)"].diff()

# Plot first difference
plt.figure(figsize=(12, 6))
plt.plot(df.index, df["rig_change"], label="Change in Rigs", color="red")
plt.axhline(0, color="black", linestyle="--")
plt.xlabel("Time")
plt.ylabel("Change in Rigs")
plt.title("Change in Active Well Service Rig Count Over Time")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# A differenced time series shows the month-to-month changes rather than the levels, helping identify trends and shocks.

# %%
# Reshape data using melt
df_melted = df.reset_index().melt(id_vars=["Month"], value_vars=["Crude Oil and Natural Gas Rotary Rigs in Operation, Onshore (Number of Rigs)", "Crude Oil and Natural Gas Rotary Rigs in Operation, Offshore (Number of Rigs)"], var_name="Rig Type", value_name="Rig Count")

# Line plot for onshore and offshore rigs
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_melted, x="Month", y="Rig Count", hue="Rig Type")
plt.xlabel("Time")
plt.ylabel("Number of Rigs")
plt.title("Onshore vs. Offshore Rigs Over Time")
plt.legend()
plt.grid()
plt.show()
